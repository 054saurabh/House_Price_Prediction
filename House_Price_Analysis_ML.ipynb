# %% [markdown]
# # # import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # # Load_Data_Set

# %%
data=pd.read_csv("C:\\Users\\srbhk\\OneDrive\\Documents\\Bangalore House Price.zip")

# %%
data.sample(5)
# Out:
#                   area_type   availability              location       size  \
# 1291   Super built-up  Area  Ready To Move       Dooravani Nagar      3 BHK
# 1274   Super built-up  Area         20-Dec        Jalahalli West      2 BHK
# 477    Super built-up  Area  Ready To Move  Ring Road Nagarbhavi      4 BHK
# 6182         Built-up  Area  Ready To Move            Whitefield  4 Bedroom
# 10418  Super built-up  Area  Ready To Move            Whitefield      2 BHK
#
#        society total_sqft  bath  balcony  price
# 1291   Puceswn       1596   3.0      1.0  105.0
# 1274       NaN       1250   2.0      1.0   62.0
# 477        NaN       4800   4.0      NaN  235.0
# 6182   Prtates       4000   4.0      3.0  380.0
# 10418  SSthamh       1340   2.0      2.0   41.0

# %%
data.head(5)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.tail(5)
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %% [markdown]
# # # Handel null_value

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
data.isnull().sum()/data.shape[0]
# Out:
# area_type       0.000000
# availability    0.000000
# location        0.000075
# size            0.001201
# society         0.413063
# total_sqft      0.000000
# bath            0.005480
# balcony         0.045721
# price           0.000000
# dtype: float64

# %% [markdown]
# # #  Handling String and dimension reduction

# %%
data['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
data.drop(['society','availability'],axis=1,inplace=True)

# %%
data.head(5)
# Out:
#               area_type                  location       size total_sqft  bath  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK       1056   2.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2        Built-up  Area               Uttarahalli      3 BHK       1440   2.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK       1521   3.0
# 4  Super built-up  Area                  Kothanur      2 BHK       1200   2.0
#
#    balcony   price
# 0      1.0   39.07
# 1      3.0  120.00
# 2      3.0   62.00
# 3      1.0   95.00
# 4      1.0   51.00

# %%
data['size'].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: size, dtype: int64

# %%
data.head()
# Out:
#               area_type                  location       size total_sqft  bath  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK       1056   2.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2        Built-up  Area               Uttarahalli      3 BHK       1440   2.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK       1521   3.0
# 4  Super built-up  Area                  Kothanur      2 BHK       1200   2.0
#
#    balcony   price
# 0      1.0   39.07
# 1      3.0  120.00
# 2      3.0   62.00
# 3      1.0   95.00
# 4      1.0   51.00

# %%
data['bhk']=data['size'].str.split().str.get(0).astype(float)

# %%
data.drop(['size'],axis=1,inplace=True)

# %%
data.sample(5)
# Out:
#                  area_type           location total_sqft  bath  balcony  \
# 6369  Super built-up  Area       Gunjur Palya        900   2.0      1.0
# 1627  Super built-up  Area         Kanakapura        551   1.0      1.0
# 297           Carpet  Area  Maruthi Sevanagar        950   2.0      2.0
# 6915  Super built-up  Area       Vikram Nagar        950   2.0      2.0
# 964   Super built-up  Area         Seegehalli        901   2.0      1.0
#
#       price  bhk
# 6369  27.00  2.0
# 1627  30.00  1.0
# 297   47.00  2.0
# 6915  38.00  2.0
# 964   35.14  2.0

# %%
for p in data.columns:
    print("#"+p+" "+"*"*10)
    print(" ")
    print(data[p].value_counts())
    print(" ")
    print(data[p].unique())
    print("-"*60)
# Out:
# #area_type **********
#
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64
#
# ['Super built-up  Area' 'Plot  Area' 'Built-up  Area' 'Carpet  Area']
# ------------------------------------------------------------
# #location **********
#
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64
#
# ['Electronic City Phase II' 'Chikka Tirupathi' 'Uttarahalli' ...
#  '12th cross srinivas nagar banshankari 3rd stage' 'Havanur extension'
#  'Abshot Layout']
# ...

# %%
data.drop(['location'],axis=1,inplace=True)

# %%
data.head()
# Out:
#               area_type total_sqft  bath  balcony   price  bhk
# 0  Super built-up  Area       1056   2.0      1.0   39.07  2.0
# 1            Plot  Area       2600   5.0      3.0  120.00  4.0
# 2        Built-up  Area       1440   2.0      3.0   62.00  3.0
# 3  Super built-up  Area       1521   3.0      1.0   95.00  3.0
# 4  Super built-up  Area       1200   2.0      1.0   51.00  2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  object
#  1   total_sqft  13320 non-null  object
#  2   bath        13247 non-null  float64
#  3   balcony     12711 non-null  float64
#  4   price       13320 non-null  float64
#  5   bhk         13304 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 624.5+ KB

# %%
data['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def split_fun(x):
    temp=x.split("-")
    if len(temp)==2:
        return (float(temp[0]) + float(temp[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
data['total_sqft']=data['total_sqft'].apply(lambda x: split_fun(x))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  object
#  1   total_sqft  13274 non-null  float64
#  2   bath        13247 non-null  float64
#  3   balcony     12711 non-null  float64
#  4   price       13320 non-null  float64
#  5   bhk         13304 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 624.5+ KB

# %%
data.shape
# Out:
# (13320, 6)

# %%
data.head(5)
# Out:
#               area_type  total_sqft  bath  balcony   price  bhk
# 0  Super built-up  Area      1056.0   2.0      1.0   39.07  2.0
# 1            Plot  Area      2600.0   5.0      3.0  120.00  4.0
# 2        Built-up  Area      1440.0   2.0      3.0   62.00  3.0
# 3  Super built-up  Area      1521.0   3.0      1.0   95.00  3.0
# 4  Super built-up  Area      1200.0   2.0      1.0   51.00  2.0

# %% [markdown]
# # # Remove out_liers

# %%
kol=['total_sqft','bath','balcony','price','bhk']
for col in kol:
    print("   ##"+col+"-"*60)
    x=data[col]
    plt.figure(figsize=(12,9))
    plt.hist(x,bins=100)
    plt.grid()
    plt.show()
# Out:
#    ##total_sqft------------------------------------------------------------
#    ##bath------------------------------------------------------------
#    ##balcony------------------------------------------------------------
#    ##price------------------------------------------------------------
#    ##bhk------------------------------------------------------------

# %%
data.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk
# count  13274.000000  13247.000000  12711.000000  13320.000000  13304.000000
# mean    1559.626694      2.692610      1.584376    112.565627      2.803743
# std     1238.405258      1.341458      0.817263    148.971674      1.294974
# min        1.000000      1.000000      0.000000      8.000000      1.000000
# 25%     1100.000000      2.000000      1.000000     50.000000      2.000000
# 50%     1276.000000      2.000000      2.000000     72.000000      3.000000
# 75%     1680.000000      3.000000      2.000000    120.000000      3.000000
# max    52272.000000     40.000000      3.000000   3600.000000     43.000000

# %%
kol=['total_sqft','bath','balcony','price','bhk']
for col in kol:
    q1=data[col].quantile(0.25)
    q3=data[col].quantile(0.75)
    iqr=(q3-q1)
    u=q3+1.5*iqr
    l=q1-1.5*iqr
    data=data.loc[(data[col]>=l) & (data[col]<=u)]

# %%
data.head(5)
# Out:
#               area_type  total_sqft  bath  balcony  price  bhk
# 0  Super built-up  Area      1056.0   2.0      1.0  39.07  2.0
# 2        Built-up  Area      1440.0   2.0      3.0  62.00  3.0
# 3  Super built-up  Area      1521.0   3.0      1.0  95.00  3.0
# 4  Super built-up  Area      1200.0   2.0      1.0  51.00  2.0
# 5  Super built-up  Area      1170.0   2.0      1.0  38.00  2.0

# %%
data.shape
# Out:
# (10471, 6)

# %%
data.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk
# count  10471.000000  10471.000000  10471.000000  10471.000000  10471.000000
# mean    1270.682500      2.257187      1.546175     69.208805      2.403495
# std      360.441017      0.642672      0.777023     31.838869      0.659095
# min      250.000000      1.000000      0.000000      8.000000      1.000000
# 25%     1070.000000      2.000000      1.000000     46.000000      2.000000
# 50%     1215.000000      2.000000      2.000000     62.000000      2.000000
# 75%     1477.000000      3.000000      2.000000     85.150000      3.000000
# max     2550.000000      4.000000      3.000000    167.000000      4.000000

# %%
kol=['total_sqft','bath','balcony','price','bhk']
for col in kol:
    print("   ##"+col+"-"*60)
    x=data[col]
    plt.figure(figsize=(12,9))
    plt.hist(x,bins=100)
    plt.grid()
    plt.show()
# Out:
#    ##total_sqft------------------------------------------------------------
#    ##bath------------------------------------------------------------
#    ##balcony------------------------------------------------------------
#    ##price------------------------------------------------------------
#    ##bhk------------------------------------------------------------

# %%
data['per']=((data['price']*100000)/data['total_sqft'])

# %%
data['per'].mean()+3*data['per'].std()
# Out:
# 11918.549667595773

# %%
data=data.loc[(data['per']<11918.549667595773)]

# %%
data.drop(['per'],axis=1,inplace=True)

# %%
kol=['total_sqft','bath','balcony','price','bhk']
for col in kol:
    print("   ##"+col+"-"*60)
    x=data[col]
    plt.figure(figsize=(12,10))
    plt.boxplot(x)
    plt.grid()
    plt.show()
# Out:
#    ##total_sqft------------------------------------------------------------
#    ##bath------------------------------------------------------------
#    ##balcony------------------------------------------------------------
#    ##price------------------------------------------------------------
#    ##bhk------------------------------------------------------------

# %%
data.shape
# Out:
# (10258, 6)

# %%
data.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk
# count  10258.000000  10258.000000  10258.000000  10258.000000  10258.000000
# mean    1280.407921      2.248002      1.552349     68.235123      2.393449
# std      355.691763      0.629697      0.775363     31.065499      0.645519
# min      276.000000      1.000000      0.000000      8.000000      1.000000
# 25%     1075.000000      2.000000      1.000000     45.485000      2.000000
# 50%     1220.000000      2.000000      2.000000     60.430000      2.000000
# 75%     1485.000000      3.000000      2.000000     85.000000      3.000000
# max     2550.000000      4.000000      3.000000    167.000000      4.000000

# %%
data.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot: title={'center': 'total_sqft'}>,
#         <AxesSubplot: title={'center': 'bath'}>],
#        [<AxesSubplot: title={'center': 'balcony'}>,
#         <AxesSubplot: title={'center': 'price'}>],
#        [<AxesSubplot: title={'center': 'bhk'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
data.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10258 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   10258 non-null  object
#  1   total_sqft  10258 non-null  float64
#  2   bath        10258 non-null  float64
#  3   balcony     10258 non-null  float64
#  4   price       10258 non-null  float64
#  5   bhk         10258 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 561.0+ KB

# %%
data.isnull().sum()/data.shape[0]
# Out:
# area_type     0.0
# total_sqft    0.0
# bath          0.0
# balcony       0.0
# price         0.0
# bhk           0.0
# dtype: float64

# %% [markdown]
# # # Remove duplicate

# %%
data[data.duplicated()]
# Out:
#                   area_type  total_sqft  bath  balcony   price  bhk
# 156    Super built-up  Area      1200.0   2.0      2.0   50.00  2.0
# 242    Super built-up  Area       645.0   1.0      1.0   16.45  1.0
# 328    Super built-up  Area      1200.0   2.0      2.0   52.00  2.0
# 484    Super built-up  Area      1464.0   3.0      2.0   56.00  3.0
# 887    Super built-up  Area      1015.0   2.0      2.0   25.88  2.0
# ...                     ...         ...   ...      ...     ...  ...
# 13291            Plot  Area       812.0   1.0      0.0   26.00  1.0
# 13297  Super built-up  Area      1060.0   2.0      1.0   52.00  2.0
# 13313  Super built-up  Area      1345.0   2.0      1.0   57.00  3.0
# 13314  Super built-up  Area      1715.0   3.0      3.0  112.00  3.0
# 13319  Super built-up  Area       550.0   1.0      1.0   17.00  1.0
#
# [1254 rows x 6 columns]

# %%
data.duplicated().sum()
# Out:
# 1254

# %%
data=data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (9004, 6)

# %% [markdown]
# # # EDA

# %%
data.sample(6)
# Out:
#                   area_type  total_sqft  bath  balcony   price  bhk
# 10166  Super built-up  Area      1623.0   3.0      1.0   89.00  3.0
# 11510  Super built-up  Area      1245.0   2.0      2.0   43.58  3.0
# 4508         Built-up  Area      1678.0   3.0      2.0  125.00  3.0
# 2103             Plot  Area      1700.0   4.0      1.0  152.00  4.0
# 7287   Super built-up  Area      1639.0   3.0      2.0  129.00  3.0
# 9298   Super built-up  Area      1129.0   2.0      1.0   44.00  2.0

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\srbhk\AppData\Local\Temp\ipykernel_1596\2578434383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <AxesSubplot: >

# %%
plt.figure(figsize=(8,6))
sns.histplot(data[data['bhk']==1]['area_type'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data[data['bhk']==1]['price'])
plt.show()

# %%
df=data.reset_index()
df.drop(['index'],axis=1,inplace=True)

# %%
x=df.drop(columns=['price'])
y=df['price']

# %%
x
# Out:
#                  area_type  total_sqft  bath  balcony  bhk
# 0     Super built-up  Area      1056.0   2.0      1.0  2.0
# 1           Built-up  Area      1440.0   2.0      3.0  3.0
# 2     Super built-up  Area      1521.0   3.0      1.0  3.0
# 3     Super built-up  Area      1200.0   2.0      1.0  2.0
# 4     Super built-up  Area      1170.0   2.0      1.0  2.0
# ...                    ...         ...   ...      ...  ...
# 8999        Built-up  Area      1805.0   3.0      3.0  3.0
# 9000        Built-up  Area      1527.0   3.0      1.0  3.0
# 9001  Super built-up  Area      1050.0   2.0      2.0  2.0
# 9002  Super built-up  Area      1262.0   2.0      2.0  2.0
# 9003        Built-up  Area      1141.0   2.0      1.0  2.0
#
# [9004 rows x 5 columns]

# %%
x
# Out:
#                  area_type  total_sqft  bath  balcony  bhk
# 0     Super built-up  Area      1056.0   2.0      1.0  2.0
# 1           Built-up  Area      1440.0   2.0      3.0  3.0
# 2     Super built-up  Area      1521.0   3.0      1.0  3.0
# 3     Super built-up  Area      1200.0   2.0      1.0  2.0
# 4     Super built-up  Area      1170.0   2.0      1.0  2.0
# ...                    ...         ...   ...      ...  ...
# 8999        Built-up  Area      1805.0   3.0      3.0  3.0
# 9000        Built-up  Area      1527.0   3.0      1.0  3.0
# 9001  Super built-up  Area      1050.0   2.0      2.0  2.0
# 9002  Super built-up  Area      1262.0   2.0      2.0  2.0
# 9003        Built-up  Area      1141.0   2.0      1.0  2.0
#
# [9004 rows x 5 columns]

# %%
y
# Out:
# 0        39.07
# 1        62.00
# 2        95.00
# 3        51.00
# 4        38.00
#          ...
# 8999    134.00
# 9000    142.00
# 9001     52.71
# 9002     47.00
# 9003     60.00
# Name: price, Length: 9004, dtype: float64

# %% [markdown]
# #  # split the data for trainig and testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
# Split data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
# Define which columns will be transformed
numeric_features = ['total_sqft', 'bath','balcony','bhk']
categorical_features = ['area_type']

# %% [markdown]
# # #create pipe line

# %%
# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

# %%
# Create pipeline for categorical features
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
# Combine pipelines using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %% [markdown]
# # #Apply esemble technique

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble  import  RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor
from sklearn.metrics import r2_score

# %%
r1 = LinearRegression()
r2 = RandomForestRegressor(n_estimators=10, random_state=1)
r3 = KNeighborsRegressor()
r4=SVR()
er = VotingRegressor([('lr', r1), ('rf', r2), ('r3', r3),('r4',r4)])

# %%
# Add machine learning model to the pipeline
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                           ('voting', er)])

# %%
# Fit the pipeline on the training data
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['total_sqft', 'bath',
#                                                    'balcony', 'bhk']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['area_type'])])),
#                 ('voting',
#                  VotingRegressor(estimators=[('lr', LinearRegression()),
#                                              ('rf',
#                                               RandomForestRegressor(n_estimators=10,
# ...

# %%
# Make predictions on the testing data
y_pred = pipe.predict(x_test)

# %%
y_pred
# Out:
# array([55.42434147, 45.74193338, 31.40568583, ..., 56.26639963,
#        96.47624016, 79.33397265])

# %%
# Evaluate the performance of the model
accuracy = pipe.score(x_test, y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.6326598921853968

# %%
#save clean data in clean_dataset.csv
data.to_csv("clean_dataset.csv")

# %%
import pickle
pickle.dump(pipe,open('model.pkl','wb'))
